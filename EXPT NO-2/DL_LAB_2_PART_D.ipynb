# %% [markdown]
# # **PART D: DEEP LEARNING EXPERIMENT MANAGEMENT**

# %%
# Mount Google Drive
import os
from google.colab import drive

drive.mount('/content/drive')
print('NAME:     AKHIL C\nROLL NO:  24BAD007')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# NAME:     AKHIL C
# ROLL NO:  24BAD007

# %% [markdown]
# # Import required libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist

# %% [markdown]
# # Load and Prepare the Dataset

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784) / 255.0
X_test = X_test.reshape(10000, 784) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # BUILD THE MODEL

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # COMPILE THE MODEL

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # TRAIN THE MODEL

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9303 - loss: 0.2418 - val_accuracy: 0.9631 - val_loss: 0.1171
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9688 - loss: 0.1022 - val_accuracy: 0.9687 - val_loss: 0.0945
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9776 - loss: 0.0718 - val_accuracy: 0.9728 - val_loss: 0.0887
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9827 - loss: 0.0546 - val_accuracy: 0.9729 - val_loss: 0.0862
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9866 - loss: 0.0416 - val_accuracy: 0.9736 - val_loss: 0.0909

# %% [markdown]
# # SAVE THE MODEL

# %%
model.save('/content/drive/MyDrive/model.keras')

print("Model saved successfully!")
# Out:
# Model saved successfully!
